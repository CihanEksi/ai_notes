# %%
# %pip install -U langchain-ollama -qU
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import OllamaEmbeddings
modelName = 'llama3.2:1b'
embeddings =(
     OllamaEmbeddings(model=modelName)
)
embeddings
# Out:
# OllamaEmbeddings(model='llama3.2:1b', base_url=None, client_kwargs={}, mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None)

# %%
r1 = embeddings.embed_documents(
    [
    "Alpha is first letter of Greek alphabet", 
    "Beta is second letter of Greek alphabet"
    ]
    )

# %%
embeddings.embed_query('what is the second letter of Greek alphabet?')
# Out:
# [-0.028238948,
#  0.02569448,
#  -0.004780554,
#  0.019508285,
#  0.03161995,
#  -0.047535732,
#  -0.0016318287,
#  0.027055286,
#  0.001193247,
#  0.028840967,
#  0.019375043,
#  -0.048672996,
#  0.013410216,
#  0.00109127,
#  -0.021238597,
#  0.00028660818,
#  -0.00074569334,
#  -0.009774928,
#  0.024217183,
#  -0.01333932,
#  0.013276534,
#  0.019101366,
#  -0.019872062,
#  0.013629631,
#  0.0054968973,
#  0.0018853307,
#  -0.01644398,
#  -0.0017464028,
#  -0.007825591,
#  0.05068822,
#  -0.02720364,
#  -0.044170424,
#  -0.030863892,
#  0.0025215743,
#  -0.0031389939,
#  0.007441712,
#  0.004978445,
#  -0.009626528,
#  0.015489464,
#  -0.035579342,
#  0.014611528,
#  0.006103064,
#  -0.019483771,
#  0.0026063244,
#  -0.01487054,
#  0.017350523,
#  -0.0106209945,
#  -0.008926965,
#  0.0074283252,
#  -0.007279204,
#  -0.032040592,
#  0.019867264,
#  0.003250219,
#  -0.017737783,
#  -0.017824978,
#  0.008980306,
#  -0.019932942,
#  -0.004390407,
#  -0.004046219,
#  0.017337115,
# ...

# %%
## other embedding moddels 'paraphrase-multilingual'

embeddings =(
        OllamaEmbeddings(model='paraphrase-multilingual')
)
text = 'Bu bir test cümlesidir'
query = embeddings.embed_query(text)
query
# Out:
# [0.022475101,
#  -0.049954537,
#  -0.005914169,
#  -0.017172374,
#  -0.036432143,
#  0.0082032345,
#  0.016626053,
#  0.018268973,
#  0.03966072,
#  0.02798389,
#  0.08029382,
#  0.026805954,
#  -0.05125052,
#  -0.081704415,
#  0.017897109,
#  0.026043015,
#  -0.011924262,
#  0.008258398,
#  0.021622036,
#  0.040900845,
#  -0.025230058,
#  -0.0032954388,
#  0.015849208,
#  -0.020083046,
#  -0.007921907,
#  -0.0047175107,
#  0.0101825725,
#  0.0087217735,
#  0.053013485,
#  -0.010561525,
#  0.051403705,
#  0.011983275,
#  -0.050580695,
#  -0.008785673,
#  0.010297496,
#  -0.023504438,
#  0.018000485,
#  -0.020775393,
#  -0.090765,
#  0.020845482,
#  0.0067353155,
#  0.07665647,
#  0.012147293,
#  -0.022309154,
#  -0.025051814,
#  0.020529963,
#  0.053238183,
#  -0.056934465,
#  -0.046477564,
#  0.039554548,
#  -0.006709856,
#  0.11263524,
#  -0.06966887,
#  0.011305356,
#  0.066151045,
#  -0.012814623,
#  -0.011396375,
#  0.030176196,
#  0.05678164,
#  -0.016435483,
#  0.0059225014,
# ...
